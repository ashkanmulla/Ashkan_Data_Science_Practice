# %% [markdown]
# <a href="https://colab.research.google.com/github/ashkanmulla/DataScience_13_September/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
income = pd.read_csv("/content/income.csv")

# %%
income
# Out:
#    Index                 State    Y2002  ...    Y2013    Y2014    Y2015
# 0      A               Alabama  1296530  ...  1852841  1558906  1916661
# 1      A                Alaska  1170302  ...  1985302  1580394  1979143
# 2      A               Arizona  1742027  ...  1363279  1525866  1647724
# 3      A              Arkansas  1485531  ...  1591896  1360959  1329341
# 4      C            California  1685349  ...  1156536  1388461  1644607
# 5      C              Colorado  1343824  ...  1178355  1383978  1330736
# 6      C           Connecticut  1610512  ...  1582249  1503156  1718072
# 7      D              Delaware  1330403  ...  1671279  1803169  1627508
# 8      D  District of Columbia  1111437  ...  1912654  1782169  1410183
# 9      F               Florida  1964626  ...  1107448  1407784  1170389
# 10     G               Georgia  1929009  ...  1887157  1259353  1725470
# 11     H                Hawaii  1461570  ...  1517184  1948108  1150882
# ...

# %%
income.columns
# Out:
# Index(['Index', 'State', 'Y2002', 'Y2003', 'Y2004', 'Y2005', 'Y2006', 'Y2007',
#        'Y2008', 'Y2009', 'Y2010', 'Y2011', 'Y2012', 'Y2013', 'Y2014', 'Y2015'],
#       dtype='object')

# %%
income.columns[0:2]
# Out:
# Index(['Index', 'State'], dtype='object')

# %%
income.dtypes
# Out:
# Index    object
# State    object
# Y2002     int64
# Y2003     int64
# Y2004     int64
# Y2005     int64
# Y2006     int64
# Y2007     int64
# Y2008     int64
# Y2009     int64
# Y2010     int64
# Y2011     int64
# Y2012     int64
# Y2013     int64
# Y2014     int64
# Y2015     int64
# dtype: object

# %%
income['State'].dtypes
# Out:
# dtype('O')

# %%
income.Y2008 = income.Y2008.astype(float)
income.dtypes
# Out:
# Index     object
# State     object
# Y2002      int64
# Y2003      int64
# Y2004      int64
# Y2005      int64
# Y2006      int64
# Y2007      int64
# Y2008    float64
# Y2009      int64
# Y2010      int64
# Y2011      int64
# Y2012      int64
# Y2013      int64
# Y2014      int64
# Y2015      int64
# dtype: object

# %%
income.shape
# Out:
# (51, 16)

# %%
s = pd.Series([1,2,3,1,2], dtype="category")
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    1
# 4    2
# dtype: category
# Categories (3, int64): [1, 2, 3]

# %%
income.Index.unique()
# Out:
# array(['A', 'C', 'D', 'F', 'G', 'H', 'I', 'K', 'L', 'M', 'N', 'O', 'P',
#        'R', 'S', 'T', 'U', 'V', 'W'], dtype=object)

# %%
income.Index.nunique()
# Out:
# 19

# %%
pd.crosstab(income.Index,income.State)
# Out:
# State  Alabama  Alaska  Arizona  ...  West Virginia  Wisconsin  Wyoming
# Index                            ...
# A            1       1        1  ...              0          0        0
# C            0       0        0  ...              0          0        0
# D            0       0        0  ...              0          0        0
# F            0       0        0  ...              0          0        0
# G            0       0        0  ...              0          0        0
# H            0       0        0  ...              0          0        0
# I            0       0        0  ...              0          0        0
# K            0       0        0  ...              0          0        0
# L            0       0        0  ...              0          0        0
# M            0       0        0  ...              0          0        0
# N            0       0        0  ...              0          0        0
# ...

# %%
income.Index.value_counts(ascending = True)
# Out:
# H    1
# U    1
# G    1
# R    1
# L    1
# F    1
# P    1
# K    2
# T    2
# S    2
# D    2
# V    2
# C    3
# O    3
# A    4
# W    4
# I    4
# M    8
# N    8
# Name: Index, dtype: int64

# %%
income.sample(n = 5)
income.sample(frac = 0.1)
# Out:
#    Index                 State    Y2002  ...    Y2013    Y2014    Y2015
# 15     I                  Iowa  1499269  ...  1173694  1431705  1641866
# 8      D  District of Columbia  1111437  ...  1912654  1782169  1410183
# 35     O                  Ohio  1802132  ...  1840898  1880804  1573117
# 23     M             Minnesota  1729921  ...  1972021  1515366  1864553
# 18     L             Louisiana  1584734  ...  1287663  1908602  1403857
#
# [5 rows x 16 columns]

# %%
income["State"]
income.State
# Out:
# 0                  Alabama
# 1                   Alaska
# 2                  Arizona
# 3                 Arkansas
# 4               California
# 5                 Colorado
# 6              Connecticut
# 7                 Delaware
# 8     District of Columbia
# 9                  Florida
# 10                 Georgia
# 11                  Hawaii
# 12                   Idaho
# 13                Illinois
# 14                 Indiana
# 15                    Iowa
# 16                  Kansas
# 17                Kentucky
# 18               Louisiana
# 19                   Maine
# 20                Maryland
# 21           Massachusetts
# 22                Michigan
# 23               Minnesota
# 24             Mississippi
# 25                Missouri
# 26                 Montana
# 27                Nebraska
# 28                  Nevada
# 29           New Hampshire
# 30              New Jersey
# 31              New Mexico
# 32                New York
# 33          North Carolina
# ...

# %%
income[["Index","State","Y2008"]]
# Out:
#    Index                 State      Y2008
# 0      A               Alabama  1945229.0
# 1      A                Alaska  1551826.0
# 2      A               Arizona  1752886.0
# 3      A              Arkansas  1188104.0
# 4      C            California  1487315.0
# 5      C              Colorado  1875146.0
# 6      C           Connecticut  1764457.0
# 7      D              Delaware  1762096.0
# 8      D  District of Columbia  1193245.0
# 9      F               Florida  1756185.0
# 10     G               Georgia  1773090.0
# 11     H                Hawaii  1919423.0
# 12     I                 Idaho  1335481.0
# 13     I              Illinois  1871645.0
# 14     I               Indiana  1139551.0
# 15     I                  Iowa  1317983.0
# 16     K                Kansas  1949478.0
# 17     K              Kentucky  1301848.0
# 18     L             Louisiana  1185085.0
# 19     M                 Maine  1295877.0
# 20     M              Maryland  1112765.0
# ...

# %%
data = pd.DataFrame({"A" : ["John","Mary","Julia","Kenny","Henry"], "B" : ["Libra","Capricorn","Aries","Scorpio","Aquarius"]})
data
# Out:
#        A          B
# 0   John      Libra
# 1   Mary  Capricorn
# 2  Julia      Aries
# 3  Kenny    Scorpio
# 4  Henry   Aquarius

# %%
#Renaming all the variables.
data.columns = ['Names','Zodiac Signs']

# %%
data.columns
# Out:
# Index(['Names', 'Zodiac Signs'], dtype='object')
