# %% [markdown]
# <a href="https://colab.research.google.com/github/ashkanmulla/Ashkan_Data_Science_Practice/blob/main/Data_Visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
cars_data = pd.read_csv("Toyota.csv", index_col=0, na_values=["??", "????"])

# %%
cars_data
# Out:
#       Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1     13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 2     13950  24.0  41711.0   Diesel   90.0       NaN          0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# ...     ...   ...      ...      ...    ...       ...        ...   ...    ...
# 1431   7500   NaN  20544.0   Petrol   86.0       1.0          0  1300      3
# 1432  10845  72.0      NaN   Petrol   86.0       0.0          0  1300      3
# 1433   8500   NaN  17016.0   Petrol   86.0       0.0          0  1300      3
# 1434   7250  70.0      NaN      NaN   86.0       1.0          0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...      ...
# 1431    1025
# 1432    1015
# 1433    1015
# 1434    1015
# 1435    1114
#
# [1436 rows x 10 columns]

# %%
cars_data.dropna(axis=0, inplace=True)

# %%
cars_data
# Out:
#       Price   Age       KM FuelType     HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986.0   Diesel   90.0       1.0          0  2000  three
# 1     13750  23.0  72937.0   Diesel   90.0       1.0          0  2000      3
# 3     14950  26.0  48000.0   Diesel   90.0       0.0          0  2000      3
# 4     13750  30.0  38500.0   Diesel   90.0       0.0          0  2000      3
# 5     12950  32.0  61000.0   Diesel   90.0       0.0          0  2000      3
# ...     ...   ...      ...      ...    ...       ...        ...   ...    ...
# 1423   7950  80.0  35821.0   Petrol   86.0       0.0          1  1300      3
# 1424   7750  73.0  34717.0   Petrol   86.0       0.0          0  1300      3
# 1429   8950  78.0  24000.0   Petrol   86.0       1.0          1  1300      5
# 1430   8450  80.0  23000.0   Petrol   86.0       0.0          0  1300      3
# 1435   6950  76.0      1.0   Petrol  110.0       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 3       1165
# 4       1170
# 5       1170
# ...      ...
# 1423    1015
# 1424    1015
# 1429    1065
# 1430    1015
# 1435    1114
#
# [1096 rows x 10 columns]

# %%
plt.scatter(cars_data["Age"], cars_data["Price"], c="red")
plt.title("Scatter plot of Price vs Age of the cars")
plt.xlabel("Age(Months)")
plt.ylabel("Price")
plt.show()

# %%
# histogram

# %%
plt.hist(cars_data["KM"])
# Out:
# (array([ 92., 239., 331., 222., 111.,  51.,  25.,  13.,  10.,   2.]),
#  array([1.000000e+00, 2.430090e+04, 4.860080e+04, 7.290070e+04,
#         9.720060e+04, 1.215005e+05, 1.458004e+05, 1.701003e+05,
#         1.944002e+05, 2.187001e+05, 2.430000e+05]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(cars_data["KM"],
        color="green",
        edgecolor="white",
        bins=5)
plt.title("Histogram of KM")
plt.xlabel("KM")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(cars_data["KM"],
        color="green",
        edgecolor="white",
        bins=5,
        orientation="horizontal")
plt.title("Histogram of KM")
plt.xlabel("KM")
plt.ylabel("Frequency")
plt.show()

# %%
# Bar Plots

# %%
cars_data["FuelType"].value_counts()
# Out:
# Petrol    968
# Diesel    116
# CNG        12
# Name: FuelType, dtype: int64

# %%
counts = [968, 116, 12]
fuelType = ("Petrol", "Diesel", "CNG")
index = np.arange(len(fuelType))

# %%
plt.bar(index, counts, color = ['red', 'blue', 'cyan'])
plt.title("Bar plot of FuelTypes")
plt.xlabel("FuelType")
plt.ylabel("Frquency(Count)")
plt.show()

# %%
import seaborn as sns

# %%
sns.set(style="darkgrid")

# %%
sns.regplot(x=cars_data["Age"], y=cars_data["Price"])

# %%
sns.regplot(x=cars_data["Age"], y=cars_data["Price"], fit_reg=False)

# %%
sns.regplot(x=cars_data["Age"], y=cars_data["Price"], marker="*", fit_reg=False)

# %%
# hue

# %%
sns.lmplot(x="Age", y="Price", data=cars_data, hue="FuelType", fit_reg=False, legend=True)

# %%
sns.lmplot(x="Age", y="Price", data=cars_data, hue="FuelType", fit_reg=False, legend=True, palette="Set1")

# %%
sns.distplot(cars_data["Age"])

# %%
sns.distplot(cars_data["Age"], kde=False)

# %%
sns.distplot(cars_data["Age"], bins=5)

# %%
# countplot

# %%
sns.countplot(x="FuelType", data=cars_data)

# %%
sns.countplot(x="FuelType", data=cars_data, hue="Automatic")

# %%
pd.crosstab(index = cars_data["Automatic"], columns=cars_data["FuelType"], dropna=True)
# Out:
# FuelType   CNG  Diesel  Petrol
# Automatic
# 0           12     116     910
# 1            0       0      58

# %%
# Box and Whiskers plot

# %%
sns.boxplot(y=cars_data["Price"])

# %%
sns.boxplot(x="FuelType", y=cars_data["Price"], hue="Automatic", data=cars_data)

# %%
f, (ax_box, ax_hist) = plt.subplots(2, gridspec_kw= {"height_ratios": (.25, .75)})

# %%
sns.boxplot(cars_data["Price"], ax=ax_box)

# %%
sns.distplot(cars_data["Price"], ax=ax_hist, kde=False)

# %%
f

# %%
f.savefig("Price.jpeg")

# %%
cars_data.head()
# Out:
#    Price   Age       KM FuelType    HP  MetColor  Automatic    CC  Doors  \
# 0  13500  23.0  46986.0   Diesel  90.0       1.0          0  2000  three
# 1  13750  23.0  72937.0   Diesel  90.0       1.0          0  2000      3
# 3  14950  26.0  48000.0   Diesel  90.0       0.0          0  2000      3
# 4  13750  30.0  38500.0   Diesel  90.0       0.0          0  2000      3
# 5  12950  32.0  61000.0   Diesel  90.0       0.0          0  2000      3
#
#    Weight
# 0    1165
# 1    1165
# 3    1165
# 4    1170
# 5    1170

# %%
df_ft = cars_data.groupby("FuelType")

# %%
df_ft

# %%
df_ft.describe()
# Out:
#           Price                                                              \
#           count          mean          std     min     25%     50%      75%
# FuelType
# CNG        12.0   8950.833333  2269.262829  5250.0  7677.5  8725.0   9962.5
# Diesel    116.0  10550.956897  5233.610064  4350.0  7325.0  8950.0  11950.0
# Petrol    968.0  10780.233471  3408.043316  5250.0  8500.0  9940.0  11950.0
#
#                      Age             ...      CC         Weight               \
#               max  count       mean  ...     75%     max  count         mean
# FuelType                             ...
# CNG       12950.0   12.0  57.750000  ...  1600.0  1600.0   12.0  1101.583333
# Diesel    31275.0  116.0  52.801724  ...  2000.0  2000.0  116.0  1154.586207
# Petrol    24500.0  968.0  55.978306  ...  1600.0  1800.0  968.0  1063.340909
#
#
#                 std     min      25%     50%      75%     max
# FuelType
# CNG       17.860359  1075.0  1083.75  1106.0  1119.00  1121.0
# Diesel    66.743776  1095.0  1115.00  1135.0  1156.25  1480.0
# Petrol    40.058663  1000.0  1035.00  1060.0  1075.00  1615.0
#
# [3 rows x 64 columns]

# %%
df_ft.describe().T
# Out:
# FuelType              CNG        Diesel        Petrol
# Price  count    12.000000    116.000000    968.000000
#        mean   8950.833333  10550.956897  10780.233471
#        std    2269.262829   5233.610064   3408.043316
#        min    5250.000000   4350.000000   5250.000000
#        25%    7677.500000   7325.000000   8500.000000
# ...                   ...           ...           ...
# Weight min    1075.000000   1095.000000   1000.000000
#        25%    1083.750000   1115.000000   1035.000000
#        50%    1106.000000   1135.000000   1060.000000
#        75%    1119.000000   1156.250000   1075.000000
#        max    1121.000000   1480.000000   1615.000000
#
# [64 rows x 3 columns]
